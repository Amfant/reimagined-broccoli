# %% [markdown]
# <a href="https://colab.research.google.com/github/Amfant/reimagined-broccoli/blob/Project-1/Plotting_Against_Astro_5205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.ascii

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# tab = astropy.io.ascii.read("/content/drive/My Drive/Colab Notebooks/PS_2020.12.15_09.21.06.csv") # For 2020
tab = astropy.io.ascii.read("/content/drive/My Drive/Colab Notebooks/PS_2025.01.16_06.39.23.csv") # For 2025

# %%
# This is to print out the names of all columns in the table
tab.colnames
# Out:
# ['pl_name',
#  'hostname',
#  'default_flag',
#  'sy_snum',
#  'sy_pnum',
#  'discoverymethod',
#  'disc_year',
#  'disc_facility',
#  'soltype',
#  'pl_controv_flag',
#  'pl_refname',
#  'pl_orbper',
#  'pl_orbpererr1',
#  'pl_orbpererr2',
#  'pl_orbperlim',
#  'pl_orbsmax',
#  'pl_orbsmaxerr1',
#  'pl_orbsmaxerr2',
#  'pl_orbsmaxlim',
#  'pl_rade',
#  'pl_radeerr1',
#  'pl_radeerr2',
#  'pl_radelim',
#  'pl_radj',
#  'pl_radjerr1',
#  'pl_radjerr2',
#  'pl_radjlim',
#  'pl_bmasse',
#  'pl_bmasseerr1',
#  'pl_bmasseerr2',
#  'pl_bmasselim',
#  'pl_bmassj',
#  'pl_bmassjerr1',
#  'pl_bmassjerr2',
#  'pl_bmassjlim',
#  'pl_bmassprov',
#  'pl_orbeccen',
#  'pl_orbeccenerr1',
#  'pl_orbeccenerr2',
#  'pl_orbeccenlim',
#  'pl_insol',
#  'pl_insolerr1',
#  'pl_insolerr2',
#  'pl_insollim',
#  'pl_eqt',
#  'pl_eqterr1',
#  'pl_eqterr2',
#  'pl_eqtlim',
#  'ttv_flag',
#  'st_refname',
#  'st_spectype',
#  'st_teff',
#  'st_tefferr1',
#  'st_tefferr2',
#  'st_tefflim',
#  'st_rad',
# ...

# %% [markdown]
# pl_orbper, pl_orbsmax, pl_rade, pl_bmassj

# %%
np.unique(tab["discoverymethod"])
# Out:
# <Column name='discoverymethod' dtype='str29' length=11>
#                    Astrometry
#               Disk Kinematics
#     Eclipse Timing Variations
#                       Imaging
#                  Microlensing
# Orbital Brightness Modulation
#                 Pulsar Timing
#   Pulsation Timing Variations
#               Radial Velocity
#                       Transit
#     Transit Timing Variations

# %%
# Creating lists for each stat we will plot
planet_radius = list(tab["pl_rade"])
planet_mass = list(tab["pl_bmassj"])
orbital_period = list(tab["pl_orbper"])
smax = list(tab["pl_orbsmax"])
discovery = list(tab["discoverymethod"])

# Confirming each list has the same length
print(len(planet_radius))
print(len(planet_mass))
print(len(orbital_period))
print(len(smax))
print(len(discovery))

# Appending lists with data for solar system planets
planet_radius.extend([0.38, 0.95, 1, 0.53, 11, 9.5, 4, 3.9])
planet_mass.extend([0.0001731, 0.002564, 0.003147, 0.0003367, 1, 0.2994, 0.4574, 0.05395])
orbital_period.extend([88, 225, 365, 687, 4333, 10759, 30687, 60190])
smax.extend([0.3871, 0.7233, 1, 1.524, 5.204, 9.573, 19.17, 30.18])
# Closest analogue for how solar system planets were discovered
discovery.extend(["Sight", "Sight", "Sight", "Sight", "Sight", "Sight", "Sight", "Sight"])

#Confirming that we have added 8 data points to each list
print(len(planet_radius))
print(len(planet_mass))
print(len(orbital_period))
print(len(smax))
print(len(discovery))
# Out:
# 38063
# 38063
# 38063
# 38063
# 38063
# 38071
# 38071
# 38071
# 38071
# 38071

# %%
plt.plot(planet_mass[0:38063], orbital_period[0:38063], "b.")
plt.plot(planet_mass[38063:38071], orbital_period[38063:38071], "r.")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Mass [M$_{Jupiter}$]")
plt.ylabel("Period [Days]")
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/core/shape_base.py:65: UserWarning: Warning: converting a masked element to nan.
#   ary = asanyarray(ary)
# Text(0, 0.5, 'Period [Days]')

# %%
plt.plot(planet_mass[0:38063], smax[0:38063], "b.")
plt.plot(planet_mass[38063:38071], smax[38063:38071], "r.")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Mass [M$_{Jupiter}$]")
plt.ylabel("Semimajor axis (AU)")
# Out:
# Text(0, 0.5, 'Semimajor axis (AU)')

# %%
plt.plot(planet_radius[0:38063], orbital_period[0:38063], "b.")
plt.plot(planet_radius[38063:38071], orbital_period[38063:38071], "r.")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Radius [R$_{Earth}$]")
plt.ylabel("Period [Days]")
# Out:
# Text(0, 0.5, 'Period [Days]')

# %%
plt.plot(planet_radius[0:38063], smax[0:38063], "b.")
plt.plot(planet_radius[38063:38071], smax[38063:38071], "r.")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Radius [R$_{Earth}$]")
plt.ylabel("Semimajor axis [AU]")
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/core/shape_base.py:65: UserWarning: Warning: converting a masked element to nan.
#   ary = asanyarray(ary)
# Text(0, 0.5, 'Semimajor axis [AU]')
